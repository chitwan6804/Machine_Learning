# %% [markdown]
# ## Heart Disease Prediction

# %%
import pandas as pd

# Loading the data
data = pd.read_csv('heart.csv')

# Display the first few rows of the dataframe
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Looking for Correlations

# %%
corr_matrix = data.corr()

# %%
corr_matrix['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.434854
# thalach     0.422895
# slope       0.345512
# restecg     0.134468
# fbs        -0.041164
# chol       -0.099966
# trestbps   -0.138772
# age        -0.229324
# sex        -0.279501
# thal       -0.337838
# ca         -0.382085
# exang      -0.438029
# oldpeak    -0.438441
# Name: target, dtype: float64

# %% [markdown]
# ## Processing Data:

# %%
#Splitting data as feautures and target value
Features = data.iloc[:, :-1]  # All columns except the last one
Target = data.iloc[:, -1]     # The last column

print("Features:")
print(Features.head())
print("Target:")
print(Target.head())
# Out:
# Features:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal
# 0   2     3
# 1   0     3
# 2   0     3
# 3   1     3
# 4   3     2
# Target:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
# Splitting desrired data into train set and test set
from sklearn.model_selection import train_test_split
train_Features, test_Features , train_target , test_target = train_test_split(Features, Target, test_size=0.2, random_state=42)

# %%
print("Training Features Shape:", train_Features.shape)
print("Testing Features Shape:", test_Features.shape)
print("Training Target Shape:", train_target.shape)
print("Testing Target Shape:", test_target.shape)
# Out:
# Training Features Shape: (820, 13)
# Testing Features Shape: (205, 13)
# Training Target Shape: (820,)
# Testing Target Shape: (205,)

# %%
# Normalize the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(train_Features)
X_test = scaler.transform(test_Features)

# %%
print("First element of train_Features after scaling:")
print(X_train[0])
# Out:
# First element of train_Features after scaling:
# [-0.58584022  0.65465367  1.008275   -0.77945357 -1.93503098 -0.41403934
#  -0.9837419  -1.01909426 -0.72594894 -0.21066121  1.00526437  2.17169136
#  -0.54519316]

# %%
# Print the first element of test_target
print("First element of test_target:")
print(train_target.iloc[0])
# Out:
# First element of test_target:
# 0

# %% [markdown]
# ## Build a network

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Input(shape=(train_Features.shape[1],)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, train_target, epochs=50, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6913 - loss: 0.6578 - val_accuracy: 0.7134 - val_loss: 0.5992
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8021 - loss: 0.5321 - val_accuracy: 0.7500 - val_loss: 0.5149
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7921 - loss: 0.4341 - val_accuracy: 0.7378 - val_loss: 0.4696
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8209 - loss: 0.3501 - val_accuracy: 0.7805 - val_loss: 0.4507
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8629 - loss: 0.3082 - val_accuracy: 0.7927 - val_loss: 0.4375
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8723 - loss: 0.2946 - val_accuracy: 0.7988 - val_loss: 0.4380
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9079 - loss: 0.2693 - val_accuracy: 0.8232 - val_loss: 0.4327
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 0.2725 - val_accuracy: 0.8171 - val_loss: 0.4293
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9002 - loss: 0.2465 - val_accuracy: 0.8171 - val_loss: 0.4346
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9094 - loss: 0.2375 - val_accuracy: 0.8232 - val_loss: 0.4244
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9176 - loss: 0.2172 - val_accuracy: 0.8171 - val_loss: 0.4214
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9276 - loss: 0.2040 - val_accuracy: 0.8293 - val_loss: 0.4229
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9331 - loss: 0.2069 - val_accuracy: 0.8293 - val_loss: 0.4202
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9246 - loss: 0.1885 - val_accuracy: 0.8232 - val_loss: 0.4207
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9084 - loss: 0.2185 - val_accuracy: 0.8415 - val_loss: 0.4278
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9314 - loss: 0.1854 - val_accuracy: 0.8476 - val_loss: 0.4249
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9506 - loss: 0.1655 - val_accuracy: 0.8354 - val_loss: 0.4280
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9385 - loss: 0.1860 - val_accuracy: 0.8476 - val_loss: 0.4230
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9226 - loss: 0.2105 - val_accuracy: 0.8537 - val_loss: 0.4328
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9321 - loss: 0.1832 - val_accuracy: 0.8537 - val_loss: 0.4303
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9033 - loss: 0.2417 - val_accuracy: 0.8476 - val_loss: 0.4420
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9359 - loss: 0.1777 - val_accuracy: 0.8476 - val_loss: 0.4445
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9196 - loss: 0.1892 - val_accuracy: 0.8659 - val_loss: 0.4471
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9339 - loss: 0.1799 - val_accuracy: 0.8659 - val_loss: 0.4457
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9514 - loss: 0.1239 - val_accuracy: 0.8659 - val_loss: 0.4435
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9534 - loss: 0.1158 - val_accuracy: 0.8659 - val_loss: 0.4434
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9308 - loss: 0.1502 - val_accuracy: 0.8537 - val_loss: 0.4501
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9482 - loss: 0.1338 - val_accuracy: 0.8659 - val_loss: 0.4552
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9520 - loss: 0.1142 - val_accuracy: 0.8659 - val_loss: 0.4604
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9475 - loss: 0.1521 - val_accuracy: 0.8659 - val_loss: 0.4682
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9528 - loss: 0.1198 - val_accuracy: 0.8659 - val_loss: 0.4715
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9646 - loss: 0.1060 - val_accuracy: 0.8659 - val_loss: 0.4748
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.0999 - val_accuracy: 0.8720 - val_loss: 0.4830
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9689 - loss: 0.1029 - val_accuracy: 0.8720 - val_loss: 0.4802
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9764 - loss: 0.0822 - val_accuracy: 0.8841 - val_loss: 0.4798
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9746 - loss: 0.0850 - val_accuracy: 0.8780 - val_loss: 0.4801
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0850 - val_accuracy: 0.8902 - val_loss: 0.4932
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9751 - loss: 0.0779 - val_accuracy: 0.8780 - val_loss: 0.4896
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.0692 - val_accuracy: 0.8963 - val_loss: 0.4880
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9848 - loss: 0.0575 - val_accuracy: 0.8841 - val_loss: 0.4955
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.0481 - val_accuracy: 0.8902 - val_loss: 0.4926
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.0613 - val_accuracy: 0.9024 - val_loss: 0.4915
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.0473 - val_accuracy: 0.8902 - val_loss: 0.5042
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0384 - val_accuracy: 0.9024 - val_loss: 0.4892
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.0404 - val_accuracy: 0.9024 - val_loss: 0.4994
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9878 - loss: 0.0326 - val_accuracy: 0.8963 - val_loss: 0.5122
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0319 - val_accuracy: 0.8963 - val_loss: 0.5014
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9865 - loss: 0.0435 - val_accuracy: 0.9024 - val_loss: 0.5021
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9910 - loss: 0.0352 - val_accuracy: 0.8963 - val_loss: 0.5157
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9936 - loss: 0.0318 - val_accuracy: 0.9024 - val_loss: 0.5227

# %%
# Plotting the training and validation loss
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training Loss')  
plt.plot(epochs, val_loss_values, 'b', label='Validation Loss')  
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plotting the training and validation accuracy
import matplotlib.pyplot as plt

history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

plt.plot(epochs, acc_values, 'bo', label='Training Accuracy')  
plt.plot(epochs, val_acc_values, 'b', label='Validation Accuracy')  
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Evalute the model and predict using the model

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, test_target)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.6553
# Test Loss: 0.5559
# Test Accuracy: 0.8927

# %%
import numpy as np

predicted_probability = model.predict(X_test)

# Print the predictions based on the threshold of 0.5
for prob in predicted_probability:
    if prob > 0.5:
        print("Yes! Patient is predicted to be suffering from heart disease.")
    else:
        print("No! Patient is predicted not to be suffering from heart disease.")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# Yes! Patient is predicted to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.
# No! Patient is predicted not to be suffering from heart disease.

# %%
test_target
# Out:
# 527    1
# 359    1
# 447    0
# 31     1
# 621    0
#       ..
# 832    1
# 796    1
# 644    1
# 404    0
# 842    0
# Name: target, Length: 205, dtype: int64
